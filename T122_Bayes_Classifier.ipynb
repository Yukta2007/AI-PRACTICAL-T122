# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
print("Yukta Sonawane T122")
dataset = pd.read_csv('Wine dataset.csv')

X = dataset.iloc[:, 1:].values
y = dataset.iloc[:, 0].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=0
)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

from sklearn.naive_bayes import GaussianNB

classifier = GaussianNB()
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

print("Predicted Test Results:")
print(y_pred)
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~")

print("Actual Test Results:")
print(y_test)
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~")

from sklearn.metrics import confusion_matrix, accuracy_score

ac = accuracy_score(y_test, y_pred)
print("Model Accuracy:", round(ac * 100, 2), "%")
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~")

cm = confusion_matrix(y_test, y_pred)
print("Model Confusion Matrix:")
print(cm)
# Out:
# Yukta Sonawane T122
# Predicted Test Results:
# [1 3 2 1 2 2 1 3 2 2 3 3 1 1 3 2 1 1 3 1 1 1 1 2 2 2 2 2 2 3 1 1 2 1 1 1]
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Actual Test Results:
# [1 3 2 1 2 2 1 3 2 2 3 3 1 2 3 2 1 1 2 1 2 1 1 2 2 2 2 2 2 3 1 1 2 1 1 1]
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Model Accuracy: 91.67 %
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Model Confusion Matrix:
# [[14  0  0]
#  [ 2 13  1]
#  [ 0  0  6]]

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

print("Libraries imported")
# Out:
# Libraries imported

# %%
colnames = ['Class', 'Alcohol', 'Malic_Acid', 'Ash', 'Alcalinity_of_Ash',
            'Magnesium', 'Total_Phenols', 'Flavanoids',
            'Nonflavanoid_Phenols', 'Proanthocyanins',
            'Color_Intensity', 'Hue',
            'OD280_OD315', 'Proline']

wine_df = pd.read_csv("Wine dataset.csv", names=colnames)

print("Dataset Loaded")
print(wine_df.head())
# Out:
# Dataset Loaded
#    Class  Alcohol  Malic_Acid   Ash  Alcalinity_of_Ash  Magnesium  \
# 0  class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium
# 1      1    14.23        1.71  2.43               15.6        127
# 2      1     13.2        1.78  2.14               11.2        100
# 3      1    13.16        2.36  2.67               18.6        101
# 4      1    14.37        1.95   2.5               16.8        113
#
#    Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# 0  Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins
# 1            2.8        3.06                  0.28             2.29
# 2           2.65        2.76                  0.26             1.28
# 3            2.8        3.24                   0.3             2.81
# 4           3.85        3.49                  0.24             2.18
#
#    Color_Intensity   Hue                   OD280_OD315   Proline
# 0  Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# ...

# %%
X = wine_df.iloc[:, 1:].values
y = wine_df.iloc[:, 0].values

# %%
import pandas as pd

wine_df = pd.read_csv("Wine dataset.csv")

X = wine_df.iloc[:, 1:].values
y = wine_df.iloc[:, 0].values

# %%
from sklearn.preprocessing import StandardScaler

std = StandardScaler()
X = std.fit_transform(X)

print("Transformed Data:")
print(X)
# Out:
# Transformed Data:
# [[ 1.51861254 -0.5622498   0.23205254 ...  0.36217728  1.84791957
#    1.01300893]
#  [ 0.24628963 -0.49941338 -0.82799632 ...  0.40605066  1.1134493
#    0.96524152]
#  [ 0.19687903  0.02123125  1.10933436 ...  0.31830389  0.78858745
#    1.39514818]
#  ...
#  [ 0.33275817  1.74474449 -0.38935541 ... -1.61212515 -1.48544548
#    0.28057537]
#  [ 0.20923168  0.22769377  0.01273209 ... -1.56825176 -1.40069891
#    0.29649784]
#  [ 1.39508604  1.58316512  1.36520822 ... -1.52437837 -1.42894777
#   -0.59516041]]

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

test_size = 0.30
seed = 7
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=test_size, random_state=seed
)

model = GaussianNB()

model.fit(X_train, y_train)

print("Trained Model:")
print(model)
# Out:
# Trained Model:
# GaussianNB()

# %%
predicted = model.predict(X_test)

print("Predicted Values:")
print(predicted)
# Out:
# Predicted Values:
# [3 1 3 3 2 3 2 1 2 3 1 2 3 2 2 2 2 3 1 1 2 2 2 2 1 3 2 3 3 3 2 1 3 2 2 2 3
#  3 1 3 1 2 3 3 2 1 1 2 2 2 2 2 1 1]

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, predicted)

print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy: 100.00%

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, predicted)

print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[13  0  0]
#  [ 0 24  0]
#  [ 0  0 17]]

# %%
from sklearn.metrics import classification_report

print("Classification Report:")
print(classification_report(y_test, predicted))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        24
#            3       1.00      1.00      1.00        17
#
#     accuracy                           1.00        54
#    macro avg       1.00      1.00      1.00        54
# weighted avg       1.00      1.00      1.00        54

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc

# %%
# Convert class labels into binary format
y_test_bin = label_binarize(y_test, classes=[1, 2, 3])

# %%
# Get probability estimates for each class
y_score = model.predict_proba(X_test)

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
import matplotlib.pyplot as plt

colors = ['hotpink', 'purple', 'deeppink']

plt.figure(figsize=(8,6))

for i, color in zip(range(3), colors):
    plt.plot(
        fpr[i],
        tpr[i],
        color=color,
        linewidth=2,
        label='Class {} (AUC = {:.2f})'.format(i+1, roc_auc[i])
    )

plt.plot([0,1], [0,1], color='mediumpurple',
         linestyle='--', linewidth=2)

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve for Wine Dataset (Gaussian Naive Bayes)")
plt.legend(loc="lower right")
plt.grid(True, linestyle='--', alpha=0.4)

plt.show()
